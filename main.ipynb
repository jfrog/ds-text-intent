# %%
import pandas as pd
from utils.general_utils import *
load_dotenv()
import csv

# %%
AWS_KEY = os.getenv('AWS_KEY')
AWS_SECRET = os.getenv('AWS_SECRET')
AWS_REGION = os.getenv('AWS_REGION')
OUTPUT_PATH = os.getenv('VH_OUTPUTS_DIR')
session = Session(aws_access_key_id=AWS_KEY,
                  aws_secret_access_key=AWS_SECRET,
                  region_name=AWS_REGION)
s3 = session.resource('s3')
your_bucket = s3.Bucket('prod-is-data-science-bucket')

# %%
source_folder = 'Data_Science/Text_Data/Salesforce/EmailMessage/2019/11/17'

# %%
object_name = None
explore_bucket_s3()
for file in your_bucket.objects.all():
    if source_folder in file.key:
        object_name = file.key
# Out:
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Csat_Model/Valohai/Prod/Upload/final_prediction.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Data_Science/Text_Data/Salesforce/EmailMessage/2017/01/01/sf_EmailMessage_2_RS2021-11-23 14:30:23.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Data_Science/Text_Data/Salesforce/EmailMessage/2017/01/02/sf_EmailMessage_2_RS2021-11-23 14:30:23.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Data_Science/Text_Data/Salesforce/EmailMessage/2017/01/03/sf_EmailMessage_2_RS2021-11-23 14:30:23.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Data_Science/Text_Data/Salesforce/EmailMessage/2017/01/04/sf_EmailMessage_2_RS2021-11-23 14:30:23.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Data_Science/Text_Data/Salesforce/EmailMessage/2017/01/05/sf_EmailMessage_2_RS2021-11-23 14:30:23.csv')
# ...

# %%
object = your_bucket.Object(object_name)

# %%
object_name
# Out:
# 'Data_Science/Text_Data/Salesforce/EmailMessage/2019/11/17/sf_EmailMessage_2_RS2021-11-23 19:43:18.csv'

# %%
object.download_file('./loaded.csv')

# %%
print("a")
# Out:
# a

# %%
df = pd.read_csv('loaded.csv',
                 delimiter='\x01',
                 lineterminator='\x04',
                 usecols = ['Id','ParentId', 'Subject', 'TextBody', 'Incoming', 'CreatedDate'],
                 # usecols = ['Id', 'Account__c', 'Case__c', 'Session_Date__c', 'Background__c', 'Sales_Notes__c',
                 #             'Goal_of_the_meeting__c', 'Comments_of_client__c', 'Architecture__c', 'Internal_Notes__c',
                 #             'External_Notes__c', 'RecordTypeId'],
                 # usecols = ['Id', 'AccountId', 'Comments__c', 'Subject', 'CreatedDate'],
                 encoding='utf-8',
                 skip_blank_lines=True)

# %%
df
# Out:
#                      Id            ParentId  \
# 0    02s1r00001rLxAHAA0  5001r00002XRicdAAD
# 1    02s1r00001rLxB5AAK  5001r00002VD96qAAD
# 2    02s1r00001rLxDpAAK  5001r00002W7xDMAAZ
# 3    02s1r00001rLxHhAAK  5001r00002XRij5AAD
# 4    02s1r00001rLxJYAA0  5001r00002W6fksAAB
# ..                  ...                 ...
# 268  02s1r00001rM6ZVAA0  5001r00002WrjDfAAJ
# 269  02s1r00001rM6cUAAS  5001r00002SJSOuAAP
# 270  02s1r00001rM6dmAAC  5001r00002XRBlDAAX
# 271  02s1r00001rM6qHAAS  5001r00002XRXsYAAX
# 272  02s1r00001rM6rUAAS  5001r00002XRBlDAAX
#
#                                                Subject  \
# 0                JFrog Cloud Solution Trial Activation
# 1    [#115822] SSL Connection issue to XRay after u...
# 2    [#116959] Deleting artifacts is not removing a...
# 3    Re: [#118242] bintray certificate "artifacts.a...
# 4    [#116652] [SSGA Artifactory] Backup Error Noti...
# ..                                                 ...
# ...

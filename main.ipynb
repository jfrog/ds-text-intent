csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='FreeTierFeatures/Valohai/Prod/Upload/final_prediction.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='ProUpsell/Valohai/Prod/Upload/final_prediction.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Pro_To_Pro_X/Valohai/Prod/Upload/final_prediction.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Pro_To_Pro_X/Valohai/Staging/Upload/final_prediction.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='ProxChurn/Valohai/Prod/Upload/final_prediction.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Text_Data/')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Text_Data/*')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Text_Data/EmailMessage/Loaded/emailmessage20210804_131844.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Text_Data/EmailMessage/Loaded/emailmessage20210808_125620.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Text_Data/EmailMessage/Loaded/emailmessage20210808_133453.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Text_Data/EmailMessage/Loaded/emailmessage20210808_133523.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Text_Data/EmailMessage/Loaded/emailmessage20210808_134326.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Text_Data/EmailMessage/Loaded/emailmessage20210808_134410.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Text_Data/EmailMessage/Loaded/emailmessage20210808_134628.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Text_Data/EmailMessage/Loaded/emailmessage20210808_134732.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Text_Data/EmailMessage/Loaded/emailmessage20210808_134809.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Text_Data/EmailMessage/Upload/')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Text_Data/EmailMessage/Upload/emailmessage.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Text_Data/Task/Loaded/task20210804_130456.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Text_Data/Task/Loaded/task20210804_131720.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Text_Data/Task/Upload/task.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Text_Data/TechnicalInfo/Loaded/technicalinfo20210804_131656.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='Text_Data/TechnicalInfo/Upload/technicalinfo.csv')
# s3.ObjectSummary(bucket_name='prod-is-data-science-bucket', key='UpsellToEnt/Valohai/Prod/Upload/final_prediction.csv')

# %%
object = your_bucket.Object(object_name)

# %%
object_name
# Out:
# 'Data_Science/Text_Data/Salesforce/EmailMessage/2021/10/26/sf_EmailMessage_2_RS2021-10-28 06:59:52.csv'

# %%
object.download_file('./loaded.csv')

# %%
print("a")
# Out:
# a

# %%
df = pd.read_csv('data/loaded_source.csv')
# Out:
# /Users/yotaml/PycharmProjects/ds-text-intent/final_venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df
# Out:
#                                                         Id  \
# 0                                       02s69000028d7PEAAY
# 1        So to conclude, all other LDAP accounts are wo...
# 2              We might be looking at the wrong logs here.
# 3        From the previous screenshot, the replication ...
# 4        If replication throws and 401, it should be be...
# ...                                                    ...
# 5457139                                      Best regards,
# 5457140                                         Harel erez
# 5457141                                      JFrog Support
# 5457142                  Check your ticket status: #182828
# 5457143                    ref:_00D20M3v0._500693YfToA:ref
#
#                    ParentId                         Subject      TextBody  \
# 0        50069000031s1w2AAA  [#153870] Ldap Account lockout  Hello Ramya,
# 1                       NaN                             NaN           NaN
# 2                       NaN                             NaN           NaN
# 3                       NaN                             NaN           NaN
# 4                       NaN                             NaN           NaN
# ...                     ...                             ...           ...
# 5457139                 NaN                             NaN           NaN
# 5457140                 NaN                             NaN           NaN
# 5457141                 NaN                             NaN           NaN
# 5457142                 NaN                             NaN           NaN
# 5457143               False    2021-11-06T22:22:11.000+0000           NaN
#
#         Incoming CreatedDate Unnamed: 6
# 0            NaN         NaN        NaN
# 1            NaN         NaN        NaN
# 2            NaN         NaN        NaN
# 3            NaN         NaN        NaN
# 4            NaN         NaN        NaN
# ...          ...         ...        ...
# 5457139      NaN         NaN        NaN
# 5457140      NaN         NaN        NaN
# 5457141      NaN         NaN        NaN
# 5457142      NaN         NaN        NaN
# 5457143      NaN         NaN        NaN
#
# [5457144 rows x 7 columns]
